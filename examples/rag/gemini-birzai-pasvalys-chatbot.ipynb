# %%
from dotenv import load_dotenv
import os

# Load environment variables from .env file
load_dotenv()

# Get the OpenAI API key
openai_key = os.getenv('GEMINI_API_KEY')

if openai_key:
    print("Gemini API key loaded successfully.")

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = (
    "./data/Pasvalys.pdf"
)

loader = PyPDFLoader(file_path)

pasvalys_documents = loader.load()

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = (
    "./data/birzai.pdf"
)

loader = PyPDFLoader(file_path)

birzai_documents = loader.load()

from rich import print

print(birzai_documents)

# %%
merged_documents = pasvalys_documents + birzai_documents

print(merged_documents)
# Out:
# [
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:18:27+00:00',
#             'title': 'Pasvalys - Wikipedia',
#             'moddate': '2025-03-12T17:18:27+00:00',
#             'source': './data/Pasvalys.pdf',
#             'total_pages': 4,
#             'page': 0,
#             'page_label': '1'
#         },
#         page_content="Pasvalys\nCity\nCoat of arms\nLocation of Pasvalys\nCoordinates: 56°3′34″N
# 24°24′13″E\nCountry\n  Lithuania\nEthnographic region Aukštaitija\nCounty\n  Panevėžys County\nMunicipality
# Pasvalys district\nmunicipality\nCapital of Pasvalys district\nmunicipality\nPasvalys city eldership\nPasvalys
# rural eldership\nFirst mentioned 1497\nGranted city rights 1946\nPopulation (2023)\nPasvalys\nPasvalys (
# pronunciation ⓘ) is a city in Panevėžys\nCounty, Lithuania, located near the bank of the\nSvalia River.\nIn 1557,
# the Treaty of Pasvalys was signed in the\ntown, which provoked Ivan IV of Russia to start the\nLivonian War.
# Pasvalys has mineral spring waters –\nin 1923 physician K. Armonas created a small\nsanatorium. At this time about
# 200 people spent time\nin sanatorium yearly.\nSoviet occupation and mass deportations in 1941\nwere devastating –
# most of the most active teachers\nand civil servants, intellectuals were deported to\nremote regions in Russia and
# Central Asia.\nIn August 1941, 1349 Jews from the village and the\nsurroundings were executed by an Einsatzgruppen
# of\nGermans and local collaborators as mentioned in the\nJäger Report.[1]\nAfter 1944 Soviet mass deportations
# started again –\nthe main target were farmers and their families.\nHundreds of families were deported. The program
# of\nforced collectivisation has started.[2]\nSince 1947 partisans of Pasvalys district fought\nagainst Soviet
# occupants. Pasvalys' partisans\nbelonged to Algimantas military district (apygarda),\nlater - to Vytis military
# district of the Lithuanian\npartisans. Most of the partisans operated in Žalioji\nrinktinė (The Green Squad), which
# was based in\nŽalioji giria (The Green Forest).[3]\nPasvalys Gimnasium of Petras Vileisis.\nLėvens primary
# school\nPasvalys\nHistory\nEducation"
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:18:27+00:00',
#             'title': 'Pasvalys - Wikipedia',
#             'moddate': '2025-03-12T17:18:27+00:00',
#             'source': './data/Pasvalys.pdf',
#             'total_pages': 4,
#             'page': 1,
#             'page_label': '2'
#         },
#         page_content='• Total 6,411\nTime zone UTC+2 (EET)\n • Summer (DST) UTC+3 (EEST)\nWebsite www.pasvalys.lt
# (http://\nwww.pasvalys.lt)\nPasvalio Svalios gymnasium\nPasvalys is famous for its farmhouse beer and is a\npart of
# Beer Route in Lithuania.\nCheese factory owned by company Pieno Žvaigždės is located in the city.\nPasvalys has its
# basketball club - BC Pieno žvaigždės.\nIt also has two football clubs- SK Sanžile (defunct) and FK Pasvalys who
# play in the 4th tier of\nLithuanian football.\nPasvalys Mill Museum\nMuseum of the Pasvalys
# region\nIndustry\nSports\nMuseums'
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:18:27+00:00',
#             'title': 'Pasvalys - Wikipedia',
#             'moddate': '2025-03-12T17:18:27+00:00',
#             'source': './data/Pasvalys.pdf',
#             'total_pages': 4,
#             'page': 2,
#             'page_label': '3'
#         },
#         page_content='Treaty of Pasvalys,\nsigned between\nPolish-Lithuanian\nKing Žygimantas\nAugustas and
# the\nLivonian Order\n \nPinewood and\nstadium\n \nPasvalys stadium\n \nPasvalys Church,\nwith fractures due
# to\nearth instability visible\nPasvalys in winter\n \nThe Green Spring in\nPasvalys\nPasvalys is twinned with:\n
# Żory in Poland\n1. "Holocaust Atlas of Lithuania"
# (http://www.holocaustatlas.lt/EN/#a_atlas/search//page/1/item/\n49/).\n2. "The Collectivization of Lithuanian
# Agriculture (1940 -1952)" (http://www.lituanus.org/1963/6\n3_3_02.htm). Retrieved 26 December 2018.\n3. Apie
# pokario kovas Pasvalio krašte (http://apzvalga.eu/apie-pokario-kovas-pasvalio-kraste.h\ntml)\nOfficial Homepage
# (http://www.pasvalys.lt)\nPasvalys district municipality
# (https://web.archive.org/web/20060205185837/http://neris.mii.l\nt/towns/pasvalys/pasvalys.html)\n[1]
# (http://gimnazija.pasvalys.lt/)\nGallery\nTwin towns and Sister cities\nReferences'
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:18:27+00:00',
#             'title': 'Pasvalys - Wikipedia',
#             'moddate': '2025-03-12T17:18:27+00:00',
#             'source': './data/Pasvalys.pdf',
#             'total_pages': 4,
#             'page': 3,
#             'page_label': '4'
#         },
#         page_content='Retrieved from "https://en.wikipedia.org/w/index.php?title=Pasvalys&oldid=1244560986"'
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:17:11+00:00',
#             'title': 'Biržai - Wikipedia',
#             'moddate': '2025-03-12T17:17:11+00:00',
#             'source': './data/birzai.pdf',
#             'total_pages': 5,
#             'page': 0,
#             'page_label': '1'
#         },
#         page_content="Biržai\nCity\nBiržai Castle of the Radziwiłł family\nCoat of arms\nLocation of
# Biržai\nCoordinates: 56°12′N 24°45′E\nCountry\n  Lithuania\nEthnographic region Aukštaitija\nCounty\n  Panevėžys
# County\nMunicipality Biržai districtmunicipality\nEldership Biržai city eldership\nCapital of Biržai
# districtmunicipalityBiržai city eldershipŠirvėna eldership\nFirst mentioned 1455\nGranted Town rights
# 1589\nPopulation (2020)\n • Total 10,146\nTime zone UTC+2 (EET)\n • Summer (DST) UTC+3 (EEST)\nWebsite birzai.lt
# (https://birzai.lt/)\nPrivilege granted to Biržai by\nWładysław IV Vasa\nBiržai\nBiržai ( pronunciationⓘ, also
# known by several alternative names) is a\ncity in northern Lithuania. Famous for its reconstructed Biržai
# Castle\nmanor, the whole region is renowned for its many traditional-recipe beer\nbreweries.\nThe exact origin of
# the city name is not known, but it is derived from\nthe Lithuanian word beržas (which means birch).[1] The name of
# the\ncity in other languages includes German: Birsen; Polish: Birże, Russian:\nБиржай (and pre-1917 Биржи);
# Yiddish: בירז  ,romanized: Birzh.[2] It is\nsimplified to Birzai in English.\nThe city's first written\nmention
# dates to 1455. The\nconstruction of Biržai Castle\nbegan in 1586, and the town\nwas granted Magdeburg\nRights in
# 1589.[3] In 1575, as\npreparation for the castle's\nconstruction, a dam was built\nat the confluence of
# the\nAgluona and Apaščia Rivers,\nand the artificial Lake\nŠirvėna, covering about\n40 km2 (15 sq mi), was created.
# It is the oldest surviving artificial lake\nin Lithuania.\nThe town's history is closely associated with the
# Radziwiłł family\n(Lithuanian: Radvila). Jerzy Radziwiłł was the first noble to settle in the\ncity. Later, after
# his daughter, Barbara Radziwiłł married the Grand\nDuke of Lithuania and King of Poland Sigismund II Augustus in
# 1547,\nthe power and influence of the family grew immensely. The Radvila\nfamily established a Protestant church
# and school, and the town became\na cultural center of the Protestant Reformation in Lithuania.\nThe local community
# of Lithuanian Jews, which settled in the Duchy of\nBiržai at the end of the 16th century, was influential,
# establishing an\ninterest-free loan society, two major flour mills, and an international\nlinen export business.[2]
# The Islamic Lipka Tatars performed military,\npolice, and postal duties for the Radziwill family.[4]\nDuring the
# Wars with Sweden, Biržai Castle was an important point of\ndefense. In 1625, Gustavus Adolphus, king of Sweden,
# attacked the\ncastle with 8,000 soldiers and it was forced to surrender. The castle was\nBiržai\nName\nHistory"
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:17:11+00:00',
#             'title': 'Biržai - Wikipedia',
#             'moddate': '2025-03-12T17:17:11+00:00',
#             'source': './data/birzai.pdf',
#             'total_pages': 5,
#             'page': 1,
#             'page_label': '2'
#         },
#         page_content="Engraving of Biržai Castle and city\nin 17th century\nTyszkiewicz Palace in
# Astravas\nsuburb\nStreet of Vytautas, Birzai, 1930-40s\nPhotographer Petras Loceris (1892–\n1973)\nWork in progress
# and finished\nrenovations in 2018\nleft in ruins and was rebuilt, only to be burnt in 1655. In 1662–1669, it was
# rebuilt\nagain in the Renaissance style. On 9 March 1701, August II the Strong and Peter I of\nRussia (Peter the
# Great) signed a pact in the castle to unite their forces against\nSweden. However, in 1704 the castle was
# completely destroyed and was left in ruins\nuntil its restoration in the 1990s.\nThe town's population suffered
# greatly due to wars and religious conflicts between the\nProtestants and Catholics. In the late 18th century,
# Biržai lost its town rights. The\nRadziwiłłs lost their wealth and influence, and Biržai was sold to the
# Tyszkiewicz\nfamily to cover debts in 1811. In 1849–1862, the Tyszkiewicz family built the\nneoclassic Astravas
# Manor palace across the lake from the site of the original castle.\nIn 1869 the town had about 2,600 residents.
# Thirty years later the population had\ngrown to 4,400.\nDuring World War II, the entire Jewish population of Biržai
# was annihilated. 15 Jews\nwere shot to death by German soldiers at the Biržai Jewish cemetery in July 1941.[5]\nOn
# 8 August 1941, Gestapo and Lithuanian collaborators murdered the entire Jewish\npopulation of the town, some 2,400
# people, by shooting them to death at a mass grave\nin a forest grove 3 kilometres (1.9 miles) outside the town.[6]
# The town was almost\ncompletely burned down during the war. Oldtown was destroyed.\nIn 1968 the population reached
# 10,000. Currently there are 10,146 people living in\nBiržai.\nAfter the unrest and conflicts settled down,
# 19th-century wooden residential house\nbuilding styles prevailed. The ongoing industrial revolution at the time
# meant that\nasbestos or metal-sheet roofing was common. With the majority of buildings being\nwooden, masonry
# buildings eventually emerged to battle cold winters and hot\nsummers. In the early 20th century, central roads were
# cobblestone. During the World\nWars, the old town was destroyed and the majority of wooden buildings in the
# main\nstreet burned down.\nDuring the Soviet rule, the town's population grew to twice its previous size.
# To\naccommodate the growth, around 60 new apartment buildings were constructed and\nmain streets asphalted. There
# was also an increase in new houses being built from\nbricks instead of wood, and the majority of them were left
# unplastered.\nWith the help of the European Union's Development Assistance grants, the town was\nable to regain a
# unique style: Since 2014, numerous apartment building renovations\nwere carried out with more planned. The road
# infrastructure is also being improved\nand some new construction, built to attract visitors and to restore the
# historic\nappearance, is in progress.\nArchitecture"
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:17:11+00:00',
#             'title': 'Biržai - Wikipedia',
#             'moddate': '2025-03-12T17:17:11+00:00',
#             'source': './data/birzai.pdf',
#             'total_pages': 5,
#             'page': 2,
#             'page_label': '3'
#         },
#         page_content="Biržai Castle Arsenal reconstructed\nin 2013 to restore a historic look of\nthe Castle's
# yard\nSinkhole formed in December, 2004\n32 meters tall canoe-shaped Kirkilai\nTower with a viewpoint to
# Kirkilai\nLakes opened in 2015. The\narchitects of the observation tower\nare Giedrius Akelis, Lina Šantaraitė\nThe
# northern part of the town, along with Lake Širvėna, lies within Biržai Regional\nPark. About 9,000 sinkholes have
# been identified in the park,[7] formed abruptly after\ngypsum in the soil has been dissolved by underground water.
# Some of these holes are\ndry, while others have become small ponds or lakes filled with water from the
# many\nunderground rivers and streams. New holes appear annually. According to local\nlegend, the 20-meter-deep
# sinkhole known as Karves ola (Cow's Cave) was\ndiscovered by a farmer after his cow disappeared. A tunnel at its
# bottom leads to a\ncave and underground lake.[8]\nClimate data for Biržai (1961–1990)\nMonth Jan Feb Mar Apr May
# Jun Jul Aug Sep Oct Nov Dec Year\nRecord high°C (°F) 8.4(47.1) 13.0(55.4) 18.8(65.8) 26.1(79.0) 30.7(87.3)
# 33.3(91.9) 33.7(92.7) 33.3(91.9) 28.9(84.0) 22.7(72.9) 16.2(61.2) 10.5(50.9) 33.7(92.7)\nMean dailymaximum°C
# (°F)\n−3.1(26.4) −2.2(28.0) 2.5(36.5) 10.1(50.2) 17.6(63.7) 21.0(69.8) 22.0(71.6) 21.3(70.3) 16.2(61.2) 10.2(50.4)
# 3.6(38.5) −0.8(30.6) 9.9(49.8)\nDaily mean°C (°F) −5.7(21.7) −5.2(22.6) −1.2(29.8) 5.5(41.9) 12.1(53.8) 15.7(60.3)
# 16.7(62.1) 15.9(60.6) 11.4(52.5) 6.7(44.1) 1.5(34.7) −3.2(26.2) 5.9(42.6)\nMean dailyminimum °C(°F)\n−8.6(16.5)
# −8.4(16.9) −4.4(24.1) 1.7(35.1) 6.7(44.1) 10.3(50.5) 11.8(53.2) 11.0(51.8) 7.4(45.3) 3.4(38.1) −0.9(30.4)
# −5.9(21.4) 2.0(35.6)\nRecord low°C (°F) −35.1(−31.2) −35.5(−31.9) −29.5(−21.1) −16.7(1.9) −4.1(24.6) 0.1(32.2)
# 3.5(38.3) 0.4(32.7) −5.3(22.5) −10.8(12.6) −20.4(−4.7) −31.4(−24.5) −35.5(−31.9)\nAverageprecipitationmm
# (inches)\n32(1.3) 24(0.9) 34(1.3) 40(1.6) 52(2.0) 58(2.3) 77(3.0) 71(2.8) 64(2.5) 55(2.2) 52(2.0) 46(1.8)
# 605(23.8)\nSource: NOAA[9]\nGeography\nClimate"
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:17:11+00:00',
#             'title': 'Biržai - Wikipedia',
#             'moddate': '2025-03-12T17:17:11+00:00',
#             'source': './data/birzai.pdf',
#             'total_pages': 5,
#             'page': 3,
#             'page_label': '4'
#         },
#         page_content='Saint John the Baptist church\nBiržai panorama\nRimantas Bagdonas, wrestler, world champion
# (1965)\nJurgis Bielinis, publicist and one of the main organizers of illegal book-smuggling (knygnešiai) at the
# time of the Lithuanian press ban\nKazys Binkis, poet, playwright\nRomualdas Brazauskas, basketball
# referee\nBernardas Brazdžionis, poet\nVladas Garastas, basketball coach\nPetras Kalpokas, painter\nPinchas HaKohen
# Lintup (1851–1924), rabbi of Hasidic community\nMantas Kvedaravičius, film maker and anthropologist\nJonas Mekas,
# film maker\nAlfonsas Petrulis, signatory of the Act of Independence of Lithuania\nJerzy Radziwiłł, Great Hetman of
# Lithuania\nŽydrūnas Savickas, strongman\nJokūbas Šernas, signatory of the Act of Independence of Lithuania\nAustra
# Skujytė, olympic silver medal winner\nJanusz Skumin Tyszkiewicz\nBalys Sruoga, poet, playwright, critic, and
# literary theorist\nElchonon Wasserman, Lithuanian rabbi, disciple of Chofetz Chaim\nVytautas Laisonas, Lithuanian
# national painter\nVidmantas Jažauskas, Lithuanian painter\nFK Širvėna Biržai (football club);\nBiržai Stadium (The
# current capacity of the stadium is 1,000 seats.);\nKK Biržai (basketball club).\nVirtual Tour of Biržai
# (http://en.vietoves.lt/?id=SO44BQ3CFJ)\nOfficial website of Biržai district municipality (https://birzai.lt/)\n[1]
# (http://www.davidrumsey.com/luna/servlet/detail/RUMSEY~8~1~4414~410003:Seconde-partie-de-la-carte-d-Europe?qvq=q:Wo
# rld_Area=%22Europe%22+;sort:Pub_Date,Pub_List_No_InitialSort;lc:RUMSEY~8~1&mi=60&trs=482) Historical map of
# Lithuania by Jean Baptiste Bourguignon Anville with Birze\n1. "Lietuvos miestų pavadinimų kilmė – tik upės ir
# pavardės?" (https://www.delfi.lt/grynas/gyvenimas/lietuvos-miestu-pavadinimu-kilme-tik-upes-ir-pavardes-54756379)
# [The origin of Lithuanian city names - only rivers andsurnames?]. Delfi (in Lithuanian). 28 January 2012. Retrieved
# 29 September 2023.\n2. "BIRZAI: Kovno"
# (http://iajgs.org/cemetery/index.php?option=com_content&view=article&id=8211:birzai&catid=186:lithuania&Itemid=35).
# International Association of Jewish Genealogical Societies. Retrieved 1 July 2009.\n3. "Istorija"
# (http://www.birzai.lt/index.php?485904789) (in Lithuanian). City of Biržai. Retrieved 22 July 2009.\n4. "SUMMARY –
# ŽIEMGALA INVESTIGATIONS" (https://web.archive.org/web/20070823013003/http://www.ziemgala.lt/z/2002_02_11.html).
# Žiemgala Journal. Archived from the original (http://www.ziemgala.lt/z/2002_02_11.html) on 23 August 2007.
# Retrieved 30 June 2009.\nNotable people\nSport\nExternal links\nReferences\nFootnotes'
#     ),
#     Document(
#         metadata={
#             'producer': 'Skia/PDF m128',
#             'creator': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko)
# HeadlessChrome/128.0.0.0 Safari/537.36',
#             'creationdate': '2025-03-12T17:17:11+00:00',
#             'title': 'Biržai - Wikipedia',
#             'moddate': '2025-03-12T17:17:11+00:00',
#             'source': './data/birzai.pdf',
#             'total_pages': 5,
#             'page': 4,
#             'page_label': '5'
#         },
#         page_content='5. "Mass Murder of the Jews at Biržai Jewish Cemetery"
# (http://holocaustatlas.lt/EN/#a_atlas/search//page/1/item/148/). Holocaust Atlas of Lithuania. Vilna Gaon State
# Jewish Museum. Retrieved 27 May 2014.\n6. "Mass Murder of the Jews from Biržai at the Pakamponys Forest"
# (http://holocaustatlas.lt/EN/#a_atlas/search//page/1/item/149/). Holocaust Atlas of Lithuania. Vilna Gaon State
# Jewish Museum. Retrieved 27 May 2014.\n7. "PROJECT ENVIRONMENT"
# (https://web.archive.org/web/20121024001751/http://ec.europa.eu/youth/evs/aod/hei_form_en.cfm?EID=46000151101).
# European Commission. Archived from the original (http://ec.europa.eu/youth/evs/aod/hei_form_en.cfm?EID=46000151101)
# on 24 October 2012. Retrieved 16 June 2009.\n8. Mullett, Adam (18 June 2008). "A visit to holey ground"
# (http://www.baltictimes.com/news/articles/20715/). TheBaltic Times. Retrieved 19 June 2009.\n9. "Biržai Climate
# Normals 1961–1990" (https://www.ncei.noaa.gov/pub/data/normals/WMO/1961-1990/RA-VI/LU/26531.TXT). National Oceanic
# and Atmospheric Administration. Retrieved 22 March 2015.\nRetrieved from
# "https://en.wikipedia.org/w/index.php?title=Biržai&oldid=1252972413"'
#     )
# ]

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=3000,  # chunk size (characters)
    chunk_overlap=200,  # chunk overlap (characters)
    add_start_index=True,  # track index in original document
)
all_splits = text_splitter.split_documents(merged_documents)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 9 sub-documents.

# %%
from langchain_google_vertexai import VertexAIEmbeddings

embeddings = VertexAIEmbeddings(model="text-embedding-004", api_key=openai_key)

from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

document_ids = vector_store.add_documents(documents=all_splits)
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[7], line 3
#       1 from langchain_google_vertexai import VertexAIEmbeddings
# ----> 3 embeddings = VertexAIEmbeddings(model="text-embedding-004", api_key=openai_key)
#       5 from langchain_core.vectorstores import InMemoryVectorStore
#       7 vector_store = InMemoryVectorStore(embeddings)
#
# File c:\Users\Jauni\generative-ai-python-2025-02\.venv\Lib\site-packages\langchain_google_vertexai\embeddings.py:166, in VertexAIEmbeddings.__init__(self, model_name, project, location, request_parallelism, max_retries, credentials, **kwargs)
#     164 if model_name:
#     165     kwargs["model_name"] = model_name
# --> 166 super().__init__(
#     167     project=project,
#     168     location=location,
#     169     credentials=credentials,
#     170     request_parallelism=request_parallelism,
#     171     max_retries=max_retries,
#     172     **kwargs,
#     173 )
#     174 self.instance["max_batch_size"] = kwargs.get("max_batch_size", _MAX_BATCH_SIZE)
#     175 self.instance["batch_size"] = self.instance["max_batch_size"]
#
# File c:\Users\Jauni\generative-ai-python-2025-02\.venv\Lib\site-packages\pydantic\main.py:214, in BaseModel.__init__(self, **data)
#     212 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     213 __tracebackhide__ = True
# --> 214 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     215 if self is not validated_self:
#     216     warnings.warn(
#     217         'A custom validator is returning a value other than `self`.\n'
#     218         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     219         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     220         stacklevel=2,
#     221     )
#
# ValidationError: 1 validation error for VertexAIEmbeddings
# api_key
#   Extra inputs are not permitted [type=extra_forbidden, input_value='AIzaSyChyG8eiR5vwDVDR1RXTBQzeE8eGtJaOdc', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.10/v/extra_forbidden

# %%
from langchain import hub

prompt = hub.pull("rlm/rag-prompt")

example_messages = prompt.invoke(
    {"context": "(context goes here)", "question": "(question goes here)"}
).to_messages()

assert len(example_messages) == 1
print(example_messages[0].content)

# %%
from langchain.llms import OpenAI

llm = OpenAI(api_key=openai_key)

question = "Please compare Pasvalys and Birzai."

retrieved_docs = vector_store.similarity_search(question)
docs_content = "\n\n".join(doc.page_content for doc in retrieved_docs)
promptAnswer = prompt.invoke({"question": question, "context": docs_content})
answer = llm.invoke(promptAnswer)
print(answer)
